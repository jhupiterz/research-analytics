# %% [markdown]
# # Scrape more papers with Serpapi

# %%
# %load_ext autoreload
# %autoreload 2
from startupjh import serpapi
from startupjh import data_preprocess
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/commander/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Scrape primary results
papers_df = serpapi.serpapi_og_results()
# Out:
# Enter key words: automation container terminal

# %%
# Primary results with full citation
papers_full_cite_df = serpapi.serpapi_full_cite(papers_df)

# %%
# Citing papers of papers in papers_df
citing_papers_df = serpapi.serpapi_cited_by_list(papers_df)
# Out:
# Got citing papers from paper 0
# Got citing papers from paper 1
# Got citing papers from paper 2
# Got citing papers from paper 3
# Got citing papers from paper 4
# Got citing papers from paper 5
# Got citing papers from paper 6
# Got citing papers from paper 7
# Got citing papers from paper 8
# Got citing papers from paper 9
# Got citing papers from paper 10
# Got citing papers from paper 11
# Got citing papers from paper 12
# Got citing papers from paper 13
# Got citing papers from paper 14
# Got citing papers from paper 15
# Got citing papers from paper 16
# Got citing papers from paper 17

# %%
# Check all citing papers have a result_id
citing_papers_df.result_id.isnull().sum()
# Out:
# 0

# %%
# Citing papers with full citation
citing_papers_full_cite_df = serpapi.serpapi_full_cite(citing_papers_df)

# %% [markdown]
# # Extract key words from title in both dataframes

# %%
papers_full_cite_df = data_preprocess.extract_key_words(papers_full_cite_df)

# %%
citing_papers_full_cite_df = data_preprocess.extract_key_words(citing_papers_full_cite_df)

# %% [markdown]
# # Extract authors, year, pub_info from both dataframes

# %%
papers_full_cite_df = data_preprocess.extract_pub_info(papers_full_cite_df)
# Out:
# extracted pub_info from paper 0
# extracted pub_info from paper 1
# extracted pub_info from paper 2
# extracted pub_info from paper 3
# extracted pub_info from paper 4
# extracted pub_info from paper 5
# extracted pub_info from paper 6
# extracted pub_info from paper 7
# extracted pub_info from paper 8
# extracted pub_info from paper 9
# extracted pub_info from paper 10
# extracted pub_info from paper 11
# extracted pub_info from paper 12
# extracted pub_info from paper 13
# extracted pub_info from paper 14
# extracted pub_info from paper 15
# extracted pub_info from paper 16
# extracted pub_info from paper 17
# extracted pub_info from paper 18
# extracted pub_info from paper 19
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/commander/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
papers_full_cite_df
# Out:
#     paper_id                                              title     result_id  \
# 0          0  A multi-agent system for the automation of a p...  qljx-SC6MYEJ
# 1          1             Automation in port container terminals  hQkbtalB1OAJ
# 2          2                          Container port automation  0q7hE6UAsyEJ
# 3          3  TRACES: TRAFFIC CONTROL ENGINEERING SYSTEM A c...  wgi33W6YplUJ
# 4          4  Multi-agent system technology in a port contai...  Q4_ut9Yo1yoJ
# 5          5  Alignments between strategic content and proce...  CcJLei5JHs4J
# 6          6  Performance analysis of a new type of automate...  bIPMB1zTRUsJ
# 7          7  A Study on Application of Yard Transportaion E...  pb-3CDRxiGEJ
# 8          8  Cooperative Scheduling of AGV and ASC in Autom...  T70_WBefKj8J
# 9          9  New technologies and the transformation of wor...  4q8DAnoCKioJ
# 10        10  Automation of the Road Gate Operations Process...  v686Tqwg3CoJ
# ...

# %%
citing_papers_full_cite_df = data_preprocess.extract_pub_info(citing_papers_full_cite_df)
# Out:
# extracted pub_info from paper 0
# extracted pub_info from paper 1
# extracted pub_info from paper 2
# extracted pub_info from paper 3
# extracted pub_info from paper 4
# extracted pub_info from paper 5
# extracted pub_info from paper 6
# extracted pub_info from paper 7
# extracted pub_info from paper 8
# extracted pub_info from paper 9
# extracted pub_info from paper 10
# extracted pub_info from paper 11
# extracted pub_info from paper 12
# extracted pub_info from paper 13
# extracted pub_info from paper 14
# extracted pub_info from paper 15
# extracted pub_info from paper 16
# extracted pub_info from paper 17
# extracted pub_info from paper 18
# extracted pub_info from paper 19
# extracted pub_info from paper 20
# extracted pub_info from paper 21
# extracted pub_info from paper 22
# extracted pub_info from paper 23
# extracted pub_info from paper 24
# extracted pub_info from paper 25
# extracted pub_info from paper 26
# extracted pub_info from paper 27
# ...

# %%
citing_papers_full_cite_df
# Out:
#      paper_id  citing_paper_id  \
# 0           0                0
# 1           1                0
# 2           2                0
# 3           3                0
# 4           4                0
# ..        ...              ...
# 117       117               17
# 118       118               17
# 119       119               17
# 120       120               17
# 121       121               17
#
#                                                  title     result_id  \
# 0    MicroPort: A general simulation platform for s...  o4mmoriNu70J
# 1    Agent-based simulation of stakeholders relatio...  p-ou00crS34J
# 2    Agent based simulation architecture for evalua...  bnLMKYOdJ9YJ
# 3    Agent based simulation architecture for evalua...  oXp7vE9e2RsJ
# 4        Agent-based approaches to transport logistics  m6wq9uLSXOgJ
# ..                                                 ...           ...
# 117  Underground freight transportation. A new deve...  r2XoqTG14owJ
# ...

# %% [markdown]
# # Save both dataframes into csv files in data folder

# %%
papers_full_cite_df.to_csv("../data/more_papers.csv", index = False)
citing_papers_full_cite_df.to_csv("../data/more_citing_papers.csv", index = False)
