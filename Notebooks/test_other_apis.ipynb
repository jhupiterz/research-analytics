# %% [markdown]
# # Test other APIs

# %% [markdown]
# ## Imports

# %%
from startupjh.data_collection import unpaywall_api
from startupjh.data_collection import doaj_api
from startupjh.data_collection import core_api
from startupjh.data_collection import google_api
from startupjh.data_collection import consolidated_df
from startupjh import data_preprocess

import pandas as pd
import numpy as np

# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Test `unpaywall_api()`

# %%
df_unpaywall = unpaywall_api.unpaywall_api()
df_unpaywall()
# Out:
# Enter key words: automation container terminal

# %% [markdown]
# ## Test `doaj_api()`

# %%
df_doaj = doaj_api.doaj_api()
df_doaj
# Out:
# Enter key words: automation container terminal
#                                                 title  \
# 0   A Container Horizontal Positioning Method with...
# 1   Automation of the Road Gate Operations Process...
# 2   Feeder Topology Configuration and Application ...
# 3   Review of horizontal transport decision proble...
# 4   Evaluating the impact of long cargo dwell time...
# 5   Automated Container Terminal Production Operat...
# 6   Storage Allocation in Automated Container Term...
# 7   An Attention Mechanism Oriented Hybrid CNN-RNN...
# 8   A novel algorithm of ship structure modeling a...
# 9   The concept of the development of cargo contai...
# 10  Cooperative Scheduling of AGV and ASC in Autom...
#
#                                             key_words  \
# 0   [Container horizontal positioning, Automated c...
# 1   [container terminal, optical camera recognitio...
# 2   [feeder topology, IEC 61850, information model...
# ...

# %% [markdown]
# ## Test `core_api()`

# %%
df_core = core_api.core_api()
df_core
# Out:
# Enter key words: automation container terminal
#                                              authors  \
# 0                                  [Bagas Pamungkas]
# 1  [Takeshi Shinoda, Hideyo Inutsuka, Putu Hangga...
# 2  [Takeshi Shinoda, Hideyo Inutsuka, Putu Hangga...
# 3  [Chairunissa Kusnoaji, Iis Dewi Ratih, Iis Dew...
# 4  [Chairunissa Kusnoaji, Iis Dewi Ratih, Iis Dew...
#
#                                             abstract document_type  \
# 0  Seiring meningkatnya volume arus petikemas dan...          None
# 1  With growing ship size and demand for effectiv...          None
# 2  With growing ship size and demand for effectiv...          None
# 3  PT Terminal Petikemas Surabaya is an internati...          None
# 4  PT Terminal Petikemas Surabaya is an internati...          None
#
#                              doi                                       link  \
# 0                           None
# 1   10.12962/j25481479.v2i2.3653  https://core.ac.uk/download/290095071.pdf
# ...

# %% [markdown]
# ## Test `google_api()`

# %%
df_google = google_api.serpapi_full_cite()
df_google
# Out:
# Enter key words: automation container terminal
#                                                 title  \
# 0   A multi-agent system for the automation of a p...
# 1              Automation in port container terminals
# 2                           Container port automation
# 3   TRACES: TRAFFIC CONTROL ENGINEERING SYSTEM A c...
# 4   Multi-agent system technology in a port contai...
# 5   Alignments between strategic content and proce...
# 6   Performance analysis of a new type of automate...
# 7   A Study on Application of Yard Transportaion E...
# 8   New technologies and the transformation of wor...
# 9   Cooperative Scheduling of AGV and ASC in Autom...
# 10  Automation of the Road Gate Operations Process...
# 11  Cyber threats in maritime container terminal a...
# 12  Modeling and analysis for an automated contain...
# 13  A Study on Application of Yard Transportaion E...
# 14  Analysis of Automation Implementation in Indon...
# ...

# %% [markdown]
# ## Consolidation of all 4 dataframes

# %%
consolidated_DF = consolidated_df.get_consolidated_df()
consolidated_DF
# Out:
# Enter key words: journal impact factor
#                                                  title journal_is_oa  \
# 0    A Comparison between the Journal Impact Factor...         False
# 1    Characteristics of journal impact factors: The...         False
# 2                                Journal impact factor          True
# 3                          The Journal “Impact Factor”         False
# 4                            The journal impact factor         False
# ..                                                 ...           ...
# 130  Modifying the journal impact factor by fractio...           NaN
# 131  Improving the accuracy of institute for scient...           NaN
# 132   Journal impact measures in bibliometric research           NaN
# 133                          Impact factor distortions           NaN
# 134  The level of non-citation of articles within a...           NaN
#
#                                           journal_name published_date  \
# ...

# %%
consolidated_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           135 non-null    object
#  1   journal_is_oa   110 non-null    object
#  2   journal_name    130 non-null    object
#  3   published_date  135 non-null    object
#  4   publisher       115 non-null    object
#  5   authors         135 non-null    object
#  6   key_words       135 non-null    object
# dtypes: object(7)
# memory usage: 7.5+ KB

# %%
consolidated_DF.journal_is_oa.unique()
# Out:
# array([False, True, '', nan], dtype=object)

# %%
consolidated_DF.publisher.unique()
# Out:
# array(['Korean Society For The Sociology Of Sport',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'ASME International', 'SAGE Publications',
#        'Staats- und Universitatsbibliothek Hamburg Carl von Ossietzky',
#        'Korean Academy of Medical Sciences', 'Scientific Scholar',
#        'American Medical Association (AMA)', 'Wiley',
#        'American Chemical Society (ACS)',
#        'American Geophysical Union (AGU)', 'AIP Publishing',
#        'Informa UK Limited', 'Oxford University Press (OUP)',
#        'Ovid Technologies (Wolters Kluwer Health)', 'Emerald',
#        'Institute of Electrical and Electronics Engineers (IEEE)',
#        'American Association for the Advancement of Science (AAAS)',
#        'American Society for Microbiology', 'BMJ',
#        'Walter de Gruyter GmbH',
#        'Towarzystwo Internistow Polskich/Polish Society of Internal Medicine',
#        'Jornal de Pediatria', 'Medknow', 'AOTA Press',
# ...

# %%
from datetime import datetime

consolidated_DF['published_date'] =  pd.to_datetime(consolidated_DF['published_date'])

# %%
consolidated_DF.dtypes
# Out:
# title                     object
# journal_is_oa             object
# journal_name              object
# published_date    datetime64[ns]
# publisher                 object
# authors                   object
# key_words                 object
# dtype: object

# %%
authors = []
for index, row in consolidated_DF.iterrows():
    if type(row.authors) == list:
        str_authors = ", ".join(row.authors)
    else:
        str_authors = row.authors
    authors.append(str_authors)
consolidated_DF['authors'] = authors

# %%
consolidated_DF
# Out:
#                                                  title journal_is_oa  \
# 0    A Comparison between the Journal Impact Factor...         False
# 1    Characteristics of journal impact factors: The...         False
# 2                                Journal impact factor          True
# 3                          The Journal “Impact Factor”         False
# 4                            The journal impact factor         False
# ..                                                 ...           ...
# 130  Modifying the journal impact factor by fractio...           NaN
# 131  Improving the accuracy of institute for scient...           NaN
# 132   Journal impact measures in bibliometric research           NaN
# 133                          Impact factor distortions           NaN
# 134  The level of non-citation of articles within a...           NaN
#
#                                           journal_name published_date  \
# ...

# %%
key_words = []
for index, row in consolidated_DF.iterrows():
    key_words.append(tuple(row.key_words))
consolidated_DF['key_words'] = key_words

# %%
consolidated_DF
# Out:
#                                                  title journal_is_oa  \
# 0    A Comparison between the Journal Impact Factor...         False
# 1    Characteristics of journal impact factors: The...         False
# 2                                Journal impact factor          True
# 3                          The Journal “Impact Factor”         False
# 4                            The journal impact factor         False
# ..                                                 ...           ...
# 130  Modifying the journal impact factor by fractio...           NaN
# 131  Improving the accuracy of institute for scient...           NaN
# 132   Journal impact measures in bibliometric research           NaN
# 133                          Impact factor distortions           NaN
# 134  The level of non-citation of articles within a...           NaN
#
#                                           journal_name published_date  \
# ...

# %%
# There is one duplicated row
consolidated_DF.duplicated().sum()
# Out:
# 1

# %%
index = consolidated_DF.duplicated()[consolidated_DF.duplicated()==True]

# %%
index
# Out:
# 113    True
# dtype: bool

# %%
consolidated_DF.drop_duplicates(inplace=True)

# %%
consolidated_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 0 to 134
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           134 non-null    object
#  1   journal_is_oa   110 non-null    object
#  2   journal_name    130 non-null    object
#  3   published_date  130 non-null    datetime64[ns]
#  4   publisher       114 non-null    object
#  5   authors         134 non-null    object
#  6   key_words       134 non-null    object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 8.4+ KB

# %%
consolidated_DF.journal_is_oa.unique()
# Out:
# array([False, True, '', nan], dtype=object)

# %%
import numpy as np

consolidated_DF['journal_is_oa'] = consolidated_DF.journal_is_oa.replace(['', np.nan], 'no data')

# %%
consolidated_DF.journal_is_oa.unique()
# Out:
# array([False, True, 'no data'], dtype=object)

# %%
consolidated_DF['published_date'] = consolidated_DF['published_date'].replace(np.datetime64('NaT'), 'no data')

# %%
consolidated_DF.published_date.unique()
# Out:
# array([Timestamp('2008-09-01 00:00:00'), Timestamp('2005-04-01 00:00:00'),
#        Timestamp('2016-06-01 00:00:00'), Timestamp('1998-07-01 00:00:00'),
#        Timestamp('2006-07-01 00:00:00'), Timestamp('1995-08-01 00:00:00'),
#        Timestamp('2008-09-10 00:00:00'), Timestamp('2009-01-01 00:00:00'),
#        Timestamp('2021-06-30 00:00:00'), Timestamp('2013-01-01 00:00:00'),
#        Timestamp('2006-01-01 00:00:00'), Timestamp('2001-01-01 00:00:00'),
#        Timestamp('2020-03-01 00:00:00'), Timestamp('2009-09-09 00:00:00'),
#        Timestamp('2012-10-08 00:00:00'), Timestamp('2008-01-01 00:00:00'),
#        Timestamp('2005-09-01 00:00:00'), Timestamp('2018-07-16 00:00:00'),
#        Timestamp('2017-06-20 00:00:00'), Timestamp('1997-12-01 00:00:00'),
#        Timestamp('2000-09-01 00:00:00'), Timestamp('2017-01-17 00:00:00'),
#        Timestamp('2017-01-02 00:00:00'), Timestamp('2018-07-03 00:00:00'),
# ...

# %%
consolidated_DF.publisher.unique()
# Out:
# array(['Korean Society For The Sociology Of Sport',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'ASME International', 'SAGE Publications',
#        'Staats- und Universitatsbibliothek Hamburg Carl von Ossietzky',
#        'Korean Academy of Medical Sciences', 'Scientific Scholar',
#        'American Medical Association (AMA)', 'Wiley',
#        'American Chemical Society (ACS)',
#        'American Geophysical Union (AGU)', 'AIP Publishing',
#        'Informa UK Limited', 'Oxford University Press (OUP)',
#        'Ovid Technologies (Wolters Kluwer Health)', 'Emerald',
#        'Institute of Electrical and Electronics Engineers (IEEE)',
#        'American Association for the Advancement of Science (AAAS)',
#        'American Society for Microbiology', 'BMJ',
#        'Walter de Gruyter GmbH',
#        'Towarzystwo Internistow Polskich/Polish Society of Internal Medicine',
#        'Jornal de Pediatria', 'Medknow', 'AOTA Press',
# ...

# %%
consolidated_DF['publisher'] = consolidated_DF.publisher.replace([None, np.nan], 'no data')

# %%
consolidated_DF['publisher'].unique()
# Out:
# array(['Korean Society For The Sociology Of Sport',
#        'Springer Science and Business Media LLC', 'Elsevier BV',
#        'ASME International', 'SAGE Publications',
#        'Staats- und Universitatsbibliothek Hamburg Carl von Ossietzky',
#        'Korean Academy of Medical Sciences', 'Scientific Scholar',
#        'American Medical Association (AMA)', 'Wiley',
#        'American Chemical Society (ACS)',
#        'American Geophysical Union (AGU)', 'AIP Publishing',
#        'Informa UK Limited', 'Oxford University Press (OUP)',
#        'Ovid Technologies (Wolters Kluwer Health)', 'Emerald',
#        'Institute of Electrical and Electronics Engineers (IEEE)',
#        'American Association for the Advancement of Science (AAAS)',
#        'American Society for Microbiology', 'BMJ',
#        'Walter de Gruyter GmbH',
#        'Towarzystwo Internistow Polskich/Polish Society of Internal Medicine',
#        'Jornal de Pediatria', 'Medknow', 'AOTA Press',
# ...

# %%
consolidated_DF
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/commander/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                  title journal_is_oa  \
# 0    A Comparison between the Journal Impact Factor...         False
# 1    Characteristics of journal impact factors: The...         False
# 2                                Journal impact factor          True
# 3                          The Journal “Impact Factor”         False
# 4                            The journal impact factor         False
# ..                                                 ...           ...
# 130  Modifying the journal impact factor by fractio...           NaN
# 131  Improving the accuracy of institute for scient...           NaN
# 132   Journal impact measures in bibliometric research           NaN
# 133                          Impact factor distortions           NaN
# ...

# %%
from startupjh.data_preprocessing import data_cleaning

data_cleaning.clean_df(consolidated_DF)
# Out:
#                                                  title journal_is_oa  \
# 0    A Comparison between the Journal Impact Factor...         False
# 1    Characteristics of journal impact factors: The...         False
# 2                                Journal impact factor          True
# 3                          The Journal “Impact Factor”         False
# 4                            The journal impact factor         False
# ..                                                 ...           ...
# 130  Modifying the journal impact factor by fractio...       no data
# 131  Improving the accuracy of institute for scient...       no data
# 132   Journal impact measures in bibliometric research       no data
# 133                          Impact factor distortions       no data
# 134  The level of non-citation of articles within a...       no data
#
#                                           journal_name       published_date  \
# ...
