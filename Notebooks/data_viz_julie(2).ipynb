# %% [markdown]
# # Basic data viz with more papers

# %%
import pandas as pd
import numpy as np

# %%
papers_df = pd.read_csv("../data/more_papers.csv")
citing_papers_df = pd.read_csv("../data/more_citing_papers.csv")

# %%
papers_df.head(3)
# Out:
#    paper_id                                              title     result_id  \
# 0         0  A multi-agent system for the automation of a p...  qljx-SC6MYEJ
# 1         1             Automation in port container terminals  hQkbtalB1OAJ
# 2         2                          Container port automation  0q7hE6UAsyEJ
#
#                                                 link  \
# 0  https://www.academia.edu/download/48859036/A_m...
# 1  https://www.sciencedirect.com/science/article/...
# 2  https://link.springer.com/content/pdf/10.1007/...
#
#                                              snippet    resources_title  \
# 0  This paper presents a system architecture whic...       academia.edu
# 1  … “ Business Process Model and Notation (BPMN)...  sciencedirect.com
# 2  … The Patrick Fisherman's Island terminal is n...            no data
#
#                                       resources_link  citation_count  \
# 0  https://www.academia.edu/download/48859036/A_m...              74
# 1  https://www.sciencedirect.com/science/article/...              49
# 2                                            no data              13
#
#                cites_id versions            cluster_id  \
# 0   9309426555546589354        4   9309426555546589354
# 1  16200645956702243205        3  16200645956702243205
# 2   2428285333085990610        6   2428285333085990610
#
#                                        full_citation  \
# 0  Rebollo, Miguel, et al. "A multi-agent system ...
# 1  Martín-Soberón, Ana María, et al. "Automation ...
# 2  Nelmes, Graeme. "Container port automation." F...
#
#                                            key_words  \
# 0  ['multiagent', 'system', 'automation', 'port',...
# 1   ['automation', 'port', 'container', 'terminals']
# 2                ['container', 'port', 'automation']
#
#                              authors  \
# 0            Rebollo, Miguel, et al.
# 1  Martín-Soberón, Ana María, et al.
# 2                    Nelmes, Graeme.
#
#                                             pub_info  year
# 0   Workshop in Agents in Industry. Barcelona. 2000.  2000
# 1  Procedia-Social and Behavioral Sciences 160 (2...  2014
# 2  Field and Service Robotics. Springer, Berlin, ...  2006

# %%
citing_papers_df.head(3)
# Out:
#    paper_id  citing_paper_id  \
# 0         0                0
# 1         1                0
# 2         2                0
#
#                                                title     result_id  \
# 0  MicroPort: A general simulation platform for s...  o4mmoriNu70J
# 1  Agent-based simulation of stakeholders relatio...  p-ou00crS34J
# 2  Agent based simulation architecture for evalua...  bnLMKYOdJ9YJ
#
#                                                 link  \
# 0  https://www.sciencedirect.com/science/article/...
# 1  https://citeseerx.ist.psu.edu/viewdoc/download...
# 2  https://link.springer.com/article/10.1007/s104...
#
#                                              snippet resources_title  \
# 0  Seaport container terminals are essential node...         no data
# 1  Port management is often faced with many vexin...         psu.edu
# 2  An agent based simulator for evaluating operat...          sc.edu
#
#                                       resources_link  citation_count  \
# 0                                            no data              86
# 1  https://citeseerx.ist.psu.edu/viewdoc/download...              75
# 2  https://jmvidal.cse.sc.edu/library/henesey09b.pdf              59
#
#                cites_id versions            cluster_id  \
# 0  13671676917955594659        4  13671676917955594659
# 1   9100415059517958823        7   9100415059517958823
# 2  15431475834875834990       11  15431475834875834990
#
#                                        full_citation  \
# 0  Sun, Zhuo, et al. "MicroPort: A general simula...
# 1  Henesey, Lawrence, Theo Notteboom, and Paul Da...
# 2  Henesey, Lawrence, Paul Davidsson, and Jan A. ...
#
#                                            key_words  \
# 0  ['microport', 'general', 'simulation', 'platfo...
# 1  ['agentbased', 'simulation', 'stakeholders', '...
# 2  ['agent', 'based', 'simulation', 'architecture...
#
#                                              authors  \
# 0                                  Sun, Zhuo, et al.
# 1  Henesey, Lawrence, Theo Notteboom, and Paul Da...
# 2  Henesey, Lawrence, Paul Davidsson, and Jan A. ...
#
#                                             pub_info  year
# 0  Advanced Engineering Informatics 26.1 (2012): ...  2012
# 1  Multi-Agent Systems for Container Terminal Man...  2003
# 2  Autonomous Agents and Multi-Agent Systems 18.2...  2009

# %%
key_words_papers = []
for _, row in papers_df.iterrows():
    key_words_papers.append(row.key_words)
key_words_papers
for key_word_list in
# Out:
# ["['multiagent', 'system', 'automation', 'port', 'container', 'terminal']",
#  "['automation', 'port', 'container', 'terminals']",
#  "['container', 'port', 'automation']",
#  "['traces', 'traffic', 'control', 'engineering', 'system', 'casestudy', 'container', 'terminal', 'automation']",
#  "['multiagent', 'system', 'technology', 'port', 'container', 'terminal', 'automation']",
#  "['alignments', 'strategic', 'content', 'process', 'structure', 'case', 'container', 'terminal', 'service', 'process', 'automation']",
#  "['performance', 'analysis', 'new', 'type', 'automated', 'container', 'terminal']",
#  "['study', 'application', 'yard', 'transportaion', 'equipment', 'automation', 'system', 'container', 'terminal']",
#  "['cooperative', 'scheduling', 'agv', 'asc', 'automation', 'container', 'terminal', 'relay', 'operation', 'mode']",
#  "['new', 'technologies', 'transformation', 'work', 'skills', 'study', 'computerisation', 'automation', 'australian', 'container', 'terminals']",
#  "['automation', 'road', 'gate', 'operations', 'process', 'container', 'terminal—a', 'case', 'study', 'dct', 'gdańsk']",
#  "['cyber', 'threats', 'maritime', 'container', 'terminal', 'automation', 'systems']",
#  "['study', 'application', 'yard', 'transportaion', 'equipment', 'automation', 'system', 'container', 'terminal']",
#  "['modeling', 'analysis', 'automated', 'container', 'terminal', 'considering', 'battery', 'management']",
#  "['analysis', 'automation', 'implementation', 'indonesia', 'container', 'terminal']",
#  "['container', 'terminal', 'handling', 'technology', 'development']",
#  "['design', 'gps', 'positioning', 'control', 'forklifts', 'automation', 'container', 'dock']",
#  "['strategic', 'analysis', 'automation', 'container', 'port', 'terminals', 'bot', 'business', 'observation', 'tool']",
#  "['container', 'terminal', 'operation', 'current', 'trends', 'future', 'challenges']",
#  "['automation', 'process', 'redesign']"]
